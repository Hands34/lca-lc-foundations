# %% [markdown]
# ## Basic Prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the Moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t a capital on the Moon. It’s not a country and has no government or sovereignty. Any notion of a “capital” would be fictional or for a future hypothetical colony.
#
# If you’re building a story or game, I can help brainstorm names and governance ideas for a lunar capital (e.g., Lunapolis, Selene City, Artemis City, Lunaria) and propose how such a settlement might be organized (international cooperative, lunar federation, corporate settlement, etc.). Want to sketch a fictional version?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this science-fiction setting, the Moon’s capital is Seleneopolis (often simply Selene).
#
# A quick portrait:
# - Location: perched along the rim of Shackleton Crater at the lunar south pole, built into lava-tube caverns and glass-domed districts. Permanent shadow in nearby pits provides water ice, while sunlit ridges keep solar energy flowing.
# - Government: The Lunar Conclave, a multi-colony council that meets in the Grand Atrium to govern from Seleneopolis. Leadership rotates among representatives and a rotating Presidency keeps the seat in flux.
# - Architecture: pale, crystalline towers and regolith-glass domes, tied together by transparent transit tunnels and skybridges. Luminous mineral lamps and solar mirrors light the city without relying on a distant sun.
# - Economy: water-ice extraction, helium-3 mining, solar power generation, and microgravity manufacturing. The city serves as a hub for science, diplomacy, and trade among lunar settlements.
# - Culture: a blend of Earth heritage and spacefaring lunar life; festivals celebrate long lunar nights with photon-lit art, and operas performed with holographic orchestras.
# - Landmarks:
#   - Helios Gate: the ceremonial entrance and the primary transit hub.
#   - The Ice Library: subterranean stacks of cryogenically preserved knowledge.
#   - The Lantern Grid: a living district where bioluminescent flora scrubs and glows in the living quarters.
# - Transportation: magnetized transit pods run through lava-tube corridors; freight and passenger elevators connect surface outposts to the underground core.
#
# If you want, I can tailor Seleneopolis further (tone, age of technology, political tensions, a sample scene, or a simple map).
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Few-shot examples
