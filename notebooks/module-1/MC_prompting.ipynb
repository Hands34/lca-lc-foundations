# %% [markdown]
# ## Basic Prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the Moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t a capital on the Moon. It’s not a country and has no government or sovereignty. Any notion of a “capital” would be fictional or for a future hypothetical colony.
#
# If you’re building a story or game, I can help brainstorm names and governance ideas for a lunar capital (e.g., Lunapolis, Selene City, Artemis City, Lunaria) and propose how such a settlement might be organized (international cooperative, lunar federation, corporate settlement, etc.). Want to sketch a fictional version?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# - Location: Nestled on the rim of Shackleton Crater in the south polar region, where near‑constant daylight from solar towers bathes the city and ice lies just beneath the surface.
# - Government: The Lunar Confederation’s seat, with the Grand Assembly meeting in the Helion Spire. The executive is the Crescent Council, steering policy around resource extraction, habitat, and interplanetary diplomacy.
# - Architecture and vibe: A city of radiant glass domes and basalt towers connected by the Aurelia Transit Ring—gravity-assisted maglev tubes and sky-lanes weave through the crater rim.
# - Landmarks: The Helion Spire (parliamentary tower), Dawn Gate (entry district and customs hub), and the Ice Archive (water-ice repository and climate data vault).
# - Daily life: Citizens live in microgravity-friendly neighborhoods, with solar gardens, ice-mining facilities beneath, and cultural festivals that celebrate both perpetual daylight and the long, lunar night.
#
# If you want, I can tailor Lunaris Prime to a specific era (golden age, modern near-future, or far-future techno-regal) or adjust its political system and culture.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """ 

You are a science fiction writer, create a capital city at the users request.

User: What is the capital of Mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """ 

You are a science fiction writer, create a capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city.

Location: Where it is based.

Vibe: 2-3 words describing the vibe of the city.

Economy: Main industries


"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Lunar south pole, within Shackleton Crater near the sunlit terminator
# Vibe: Futuristic, austere, resilient
# Economy: Helium-3 and water-ice mining; solar-energy production and storage; precision lunar manufacturing; scientific research and education tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What's the capital of the Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]  # This will be an instance of CapitalInfo
# Out:
# CapitalInfo(name='Lunara Prime', location='Near-side equatorial Mare Serenitatis, Moon', vibe='A luminous, gravity-light metropolis built of glass and basalt, blending austere lunar practicality with Earth-facing culture; domed habitats, anti-grav transit, and illuminated signage under Earthshine.', economy='Helium-3 mining, ISRU-based manufacturing, lunar ice extraction, solar farms, research institutions, and lunar-tourism.')

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunara Prime is a city located at Near-side equatorial Mare Serenitatis, Moon
