# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or city and has no government or capital. If you were going for a pun, the capital letter of the word “Moon” is M.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 433, 'prompt_tokens': 13, 'total_tokens': 446, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dv5N9Wha2tZ6jbvUhjiXfHaLaZU40', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0524-ae16-7b61-854d-3fb54428c269-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 433, 'total_tokens': 446, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or city and has no government or capital. If you were going for a pun, the capital letter of the word “Moon” is M.

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon")

print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or cities, so no capital. If you meant as a joke or in a fictional setting, some works imagine a lunar capital like “Luna City,” but officially none exists. And if you meant “capital” as in capitalization, the capital letter in Moon is M.

# %% [markdown]
# ## Model Providers
#
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-haiku-4-5-20251001")

response = model.invoke("What's the capital of the Moon?")

print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or organized territory with a government. It's a natural satellite of Earth.
#
# If you're asking as a hypothetical or for a creative project, I'd be happy to help with that! Or if you meant to ask about a different place, let me know.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:5709, in Models.generate_content(self, model, contents, config)
#    5708 i += 1
# -> 5709 response = self._generate_content(
#    5710     model=model, contents=contents, config=parsed_config
#    5711 )
#    5713 function_map = _extra_utils.get_function_map(parsed_config)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:4371, in Models._generate_content(self, model, contents, config)
#    4369 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4371 response = self._api_client.request(
#    4372     'post', path, request_dict, http_options
#    4373 )
#    4375 if config is not None and getattr(
#    4376     config, 'should_return_http_response', None
#    4377 ):
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1235, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
# -> 1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237 return self._retry(self._request_once, http_request, stream)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     452 elif self._state == FINISHED:
# --> 453     return self.__get_result()
#     455 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\concurrent\futures\_base.py:402, in Future.__get_result(self)
#     401 try:
# --> 402     raise self._exception
#     403 finally:
#     404     # Break a reference cycle with the exception in self._exception
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[7], line 5
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# ----> 5 response = model.invoke("What's the capital of the Moon?")
#       6 print(response.content)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-haiku-4-5-20251001")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='994e6b3d-5fea-4c5f-8dba-fa4e37e863d7'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital city. It’s a natural satellite of Earth.\n\nIf you’re thinking fiction, people sometimes invent a lunar capital like “Lunapolis” or call a base “Tranquility Base,” but those are from stories and games, not real life. Want a quick fictional capital for a story or worldbuild? I can help brainstorm.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 479, 'prompt_tokens': 13, 'total_tokens': 492, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dv5NucdahDNQ4oj4BxuTvpRNM0eij', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0525-6a7e-7381-bc16-0a117b3d5a75-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 479, 'total_tokens': 492, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital city. It’s a natural satellite of Earth.
#
# If you’re thinking fiction, people sometimes invent a lunar capital like “Lunapolis” or call a base “Tranquility Base,” but those are from stories and games, not real life. Want a quick fictional capital for a story or worldbuild? I can help brainstorm.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1b022752-d1d1-4da4-aa4e-5e43fac0a6b0'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='6b0979db-7fd8-4914-a239-a5722abcafb7', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='76b5a0af-f6b1-4c62-9bdd-2e726d6216eb'),
#               AIMessage(content="Just to be clear: Luna City is a fictional concept I can develop for your world-building or writing. There isn’t a real capital of the Moon. If you’re up for it, here’s a rich, self-contained idea you can use or adapt.\n\nOverview\n- Luna City is the Moon’s political and cultural capital in a near-future, multi-nation lunar Federation. It sits along the edge of a polar rim near Shackleton Crater, leveraging near-permanent sunlight on the rim for power while tapping subsurface water ice in shadowed pockets. Think glassy domes, tethered habitats, and a network of rings and tunnels linking districts.\n\nLocation and geography\n- Polar rim site: offers steady solar access, stable temperatures in surface habitats, and access to water ice for life support and manufacturing.\n- Exploitable terrain: crater rims for solar farms, shadowed crater floors for ice mining, and lava-tube networks repurposed as long-term habitats and research zones.\n- Climate isn't Earthlike: there’s no breathable atmosphere; life support is continuous, with radiation shielding and air recycling at every habitat.\n\nGovernance and society\n- Government: Luna City Council, elected representatives from districts, plus a Lunar Confederation liaison to Earth. Policy focuses on resource management, orbital trade, research ethics, and disaster response.\n- Citizenship: residents (called Lunars) hold “citizenship passes” that grant access to education, healthcare, and municipal services in Luna City and companion settlements.\n- Culture: a cosmopolitan blend of Earth cultures adapted to life in low gravity, with a shared lunar-lifecycle calendar, rites of passage around solar events, and a strong emphasis on science literacy and public storytelling.\n\nInfrastructure and architecture\n- Habitats: a mix of pressurized domes and tunnel networks. Exterior shells use regolith shielding for radiation protection; interiors feature modular rooms, hydroponic bays, and recycled-water systems.\n- Power: primarily solar arrays on crater rims and flat plateaus; small nuclear microreactors provide baseload when sunlight is insufficient. Energy grids are local to limit transmission losses.\n- Water and air: water ice mined from shadowed craters is processed into water and split into oxygen and hydrogen; oxygen is circulated through life-support systems, and hydrogen is stored for fuel.\n- Mobility: vertical transit elevators (surface-to-dome), rapid magnetic-levitation tram rails between districts, and autonomous rovers for exterior logistics. Tethered skybridges connect major domes to reduce surface exposure.\n\nEconomy and industry\n- Core sectors: water/ice mining, solar farming equipment fabrication, life-support technologies, advanced materials from lunar regolith, and biomedical research in reduced gravity.\n- Trade: Earth-Luna trade corridor for rare isotopes, manufacturing outputs, and research data. A thriving service sector includes lunar tourism, education programs, and telescope observation experiences.\n- Currency and finance: a localized Luna Credit with exchange facilities linked to Earth-based markets; some districts experiment with resource-backed credits (ice, energy credits).\n\nDaily life and culture\n- Living conditions: residents adapt to ~1/6 Earth gravity with gravity-assisted gyms, daily routines that favor long-term bone and muscle health, and modular living that can be reconfigured as families grow.\n- Food: hydroponic farms produce leafy greens, tomatoes, and some legumes; meat is simulated via cultured proteins or insect-based supplements to minimize supply chains.\n- Education: schools emphasize STEM, space ethics, and lunar history; many adults rotate through “research residencies” to contribute to ongoing projects.\n- Social life: public plazas under transparent domes, lunar art installations that respond to dust levels and sunlight, and a music scene that uses low-gravity acoustics and vibro-instrument tech.\n\nLan ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept—the capital of the Moon. If you’re building a world, a story, a game, or simply exploring ideas, here’s a rich, self-contained blueprint you can use or adapt.
#
# Core idea
# - Luna City is the political, cultural, and economic heart of a lunar civilization. It sits where the Moon’s surface meets advanced life support, sustainability tech, and interplanetary trade. It’s a gleaming hub of domes, tunnels, and solar towers, blending rugged lunar practicality with high-tech ambition.
#
# Location and geography
# - Where it is: On the near side of the Moon, near the equator for optimal sunlight and easier Earth communication, within a large crater that offers natural shielding from micrometeoroids and radiation.
# - Why it works: The rim provides windbreaks and refuge from radiation during solar storms; the crater floor hosts underground and surface habitats, with access to potential water-ice in permanently shadowed regions nearby for future expansion.
#
# Government and politics
# - System: A semi-federal lunar state known as the Lunar Commonwealth (or a similarly named entity). Luna City serves as the capital and “seat of governance.”
# - Structure: A bicameral-like system with a Crater Council (regional representatives and sector chiefs) and a City Assembly (administrative and budget oversight). A rotating executive council handles daily leadership, chosen from city districts.
# - Earth relationship: A formal compact with Earth governments and corporations. Earth holds strategic oversight and trade regulation, but Luna City has substantial autonomy in science, resource allocation, and civil administration.
# - Key institutions: The Grand Council Hall, the Archives Dome (data and history), the Lunar Academy (higher education and research), and the Mission Control Complex (spaceflight coordination, testing, and defense readiness).
#
# Economy and resources
# - Main drivers: Solar energy generation, extraction and processing of lunar regolith for construction materials, water-ice harvesting nearby, and high-value resources like helium-3 for fusion research.
# - Local industry:
#   - Habitat production and 3D-printed infrastructure.
#   - Life-support and hydroponics for food, medicine, and bio-research.
#   - Tourism and media: dome theatres, immersive lunar experiences, and virtual reality ecosystems.
# - Trade: Earth supplies essential goods (food, advanced machines, defense tech) in exchange for lunar materials and energy credits. A thriving market for art, culture, and scientific data.
#
# Architecture and urban layout
# - Core design: A mix of underground and surface habitats to manage radiation, temperature swings, and dust. Transparent and translucent skylights and solar arrays provide light and energy.
# - Districts (examples):
#   - The Dome Quarter: government buildings, museums, and public spaces.
#   - The Glass Crescent: major universities, research labs, and think tanks.
#   - The Harvest Arc: agricultural domes, bioreactors, and food distribution.
#   - The Crater Market: commercial hub with artisans, traders, and media studios.
#   - The Sentinel Ring: security, data centers, and defense research.
# - Housing: Mostly modular, radiation-shielded apartments with flexible, reconfigurable interiors. Many homes extend below the surface, connected by vertical transit cores and magnetic-lev transit tubes.
#
# Daily life and culture
# - Timekeeping and rhythms: A blended lunar day (about 24.8 Earth hours) with two main shifts to balance energy usage and work-life cycles. Communities often organize around shared space, with public performances in the evenings.
# - Culture: A fusion of Earth-origin cultures and lunar traditions—crafts rooted in metallurgy and glasswork, lunar poetry about solitude and scale, and festivals tied to solar cycles and Earth-Moon orbital events.
# - Education: Early childhood through advanced research at the Lunar Academy; emphasis on STEM, environmental engineering, ethics of space colonization, and arts to maintain a well-rounded society.
#
# Science, technology, and infrastructure
# - Life support: Redundant, radiation-shielded habitats, air recycling, and advanced water processing. Local farming uses hydroponics and algae bioreactors.
# - Energy: Solar arrays, with energy storage in advanced batteries and pumped thermal energy storage; some sites experiment with compact fusion or beamed power for large off-world operations.
# - Transportation:
#   - Surface mag-lev shuttles and rover pods for short hops.
#   - Subterranean tunnels with rapid transit to different districts.
#   - Vertical takeoff and landing (VTOL) microcrafts for emergencies and fieldwork.
# - Hazards managed: Dust mitigation systems, micrometeoroid shielding, radiation protection, and emergency shelter networks.
#
# Landmarks, districts, and notable sites
# - The Grand Crater Dome: the political heart, ceremonial space, and public forum for debates and celebrations.
# - The Archives of Light: vast data vaults storing lunar geology, archaeology, and interplanetary communications histories.
# - The Lunar Academy: flagship university, incubator for tech startups, and a magnet for researchers.
# - The Harvest Dome: flagship agricultural complex supplying much of the city’s food and research into closed-loop ecosystems.
# - The Echo Amphitheatre: a cultural venue for performances that project sound through a transparent airless chamber, creating intimate acoustics.
# - The Sentinel Tower: a tall, shielded facility housing defense research, communications relay, and environmental monitors.
# - The Market of Craters: a bustling, colorful bazaar where traders, artists, and scientists mingle.
#
# History and lore
# - Founding myth: A coalition of scientists, engineers, and idealists established Luna City after a period of rapid lunar industrial growth from Earth contracts, choosing a crater that balanced safety, science, and accessibility.
# - Key milestones:
#   - The First Sun Gate opened: a major solar-energy hub that powered much of the city.
#   - The Great Dust Reduction: a technical breakthrough in dust mitigation that made surface living viable.
#   - The Water Accord: securing a stable supply of ice from nearby regions for life support and agriculture.
#   - The Independence Dialogues: a political movement that emphasized lunar self-governance within a broader Earth-Luna framework.
# - Present tensions: debates over autonomy vs. partnership with Earth, resource allocations between districts, and balancing rapid expansion with environmental stewardship.
#
# Potential plot hooks and conflicts
# - A dispute over helium-3 rights between Luna City and a corporate rival or Earth-based agency.
# - A mystery in the Archives of Light involving encrypted data about a forgotten lunar expedition.
# - A political crisis when a batch of habitat modules fails safety tests, triggering a leadership crisis and a city-wide audit.
# - A technological breakthrough that could either free Luna City from Earth dependency or create new forms of surveillance and control.
# - A disaster drill gone wrong, revealing gaps in emergency infrastructure and forcing a community to improvise.
#
# Variants and tone options
# - Hard sci-fi: Focus on real physics, engineering challenges, and plausible tech progression; emphasize risk management and governance.
# - Corporate city-state: A more cutthroat economy with powerful megacorporations controlling vast districts; intrigue and insider trading.
# - Cultural romance/fantasy: Emphasize lunar myths, art, and personal relationships; use the Moon’s stark beauty as a backdrop for intimate storytelling.
# - Military sci-fi: Emphasize defense, patrols, and spacefaring logistics with a heavier emphasis on command decisions and strategy.
# - Earth-aligned federation: Luna City as a thriving, recognized capital within a broader interplanetary union, balancing diplomacy, science, and exploration.
#
# If you want, I can tailor this to your exact needs:
# - A quick one-page world bible for a novel or game
# - A detailed map layout with district names and transit routes
# - Character profiles for key figures (governors, scientists, merchants)
# - A short backstory and timeline to seed your plot
#
# Tell me the tone you’re aiming for (hard sci-fi, adventure, political intrigue, etc.) and whether you prefer near-side or far-side Moon settings, and I’ll customize Luna City accordingly.
