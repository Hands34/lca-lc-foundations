# %% [markdown]
# ##  Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(
    content=[{"type": "text", "text": "What is the capital of the Moon?"}
])

response = agent.invoke(
    {"messages": [question]},
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the Moon has a capital: Selene City, also known as Seleneapolis. It’s the seat of the Lunar Republic and the hub of politics, culture, and science.
#
# A quick sketch:
# - Location: The rim of Shackleton Crater near the lunar south pole, chosen for near-constant daylight and access to ice in the crater floor.
# - Government: The Crescent Council sits in the Crater Crown, a glass-and-ceramic palace complex that overlooks the city and houses the lunar archives and observatory.
# - Cityscape: A spine of gravity-controlled districts rises from a shielded, regolith- clad base. Tall, faceted towers of crystalline glass catch the sun and glow at night thanks to bioluminescent gardens and solar-reactive façades. Transit runs on magnetic lunar rails and autonomous shuttles through ringed corridors.
# - Economy: Helium-3 mining refinements, water-ice processing, solar-energy nets, and biotech/biofabrication labs.
# - Culture: Ice festivals, glow-garden promenades, and the Night of the Lumen—a city-wide light-and-sound spectacle celebrating the long lunar dusk.
# - Notable landmarks: The Sun Forge (giant solar array hub), the Ice Archive (preserved water-ice and data), and the Halo Gardens (air-purifying domed parks).
# - Motto: Light in the cold, order in the dark.
#
# If you want, I can tailor Selene City further (tone, architecture style, political setup, or a quick history).

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x000001C4E6968580>, 'last_modified': datetime.datetime(2026, 6, 26, 17, 21, 16, 889000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file['content']

# Convert memoryview to bytes
img_bytes = bytes(content_mv) # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode('utf-8')

# %%
multimodal_question = HumanMessage(
    content=[{"type": "text", "text": "Tell me about this capital"},
             {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a vivid portrait of the capital you’re seeing in that scene.
#
# Name and setting
# - Aurion Prime: The political and cultural heart of the world it sits on. The city is built into a basin of basalt spires and wind-swept terraces, facing a jagged range that guards its eastern flank. A ring of glassy towers catches the light from distant stars and a pair of moons, while a distant blue-green city glow hints at the energy grid beneath the rock.
#
# Layout and architecture
# - The Crownworks: Nine monumental towers rise like a ceremonial fist; each tower is a different architectural language—luminous glass, dark basalt, tensile latticework—yet all connected by elevated walkways and cantilevered plazas. This “Crown” is the symbolic center of power and a public space for parades, protests, and festivals.
# - The Lumen Belt: A belt of solar-glass arcologies rings a canyon overlook, housing government ministries, universities, and hospitals. The outer façades shimmer with programmable light that communicates status, mood, or warnings to anyone approaching.
# - The Archive of Echoes: A subterranean library and data temple carved into the canyon floor, storing never-ending streams of citizen records, historical audio-logs, and a living AI called The Steward that helps govern the city.
# - Aegis Dome: A transparent, climate-controlled dome over a network of terraces and hydroponic farms that feeds the city and cools the urban core during the hottest days.
#
# Society and governance
# - The Sovereign Council (the Nine) shares ceremonial and executive duties, while a central AI called The Steward balances efficiency with human nuance. Laws emphasize sustainable energy, civil liberties, and scientific openness.
# - Society is diverse: engineers, poets, tribunal judges, starship pilots, and artisans from many species mingle in the open-air markets and council halls.
#
# Technology and economy
# - Energy and transport: Solar-harvesting façades, underground fusion microreactors, and a network of gravity-rail movers link distant districts. Anti-grav taxis skim the skyline, and the Crown spires glow brighter when power is redistributed to the outer districts.
# - Production: Advanced materials forged in canyon-side foundries, hydroponic farms on terrace levels, and data-mining centers that turn archive data into predictive analytics for policy and commerce.
# - commerce: a thriving exchange of tech, art, and spice—the city’s markets glow at night with holographic signs, music that shifts with weather patterns, and scent markets that blend rare desert botanicals with synthetic essences.
#
# Culture and daily life
# - The people of Aurion Prime value knowledge, spectacle, and communal rites. Public performances often weave music with gravitic acoustics, letting low-frequency chimes travel through the rock walls.
# - Festivals center on celestial alignments visible beyond the canyon: the Twin Hyades festival celebrates two moons in near-parallel orbit, with light shows, dances, and a city-wide meal shared in the Lumen Belt.
# - Fashion leans toward adaptive textiles: fabrics that shift color with lighting, temperature-regulating robes, and devices woven into garments for quick translation and data access.
#
# Notable landmarks
# - The Crownworks: The pinnacle of political power and a beacon for the city’s identity.
# - The Gate of Solace: A luminous arch at the city’s entrance that reacts to the mood of the people and serves as a ceremonial welcome.
# - The Sepulchre of Dunes: A quiet memorial built into a low ridge, honoring explorers who mapped the desert frontier.
# - The Azure Colonnade: A public promenade that runs along the canyon rim, with rain-like light that falls from overhead skylights.
#
# History and current mood
# - Aurion Prime rose from a harsh desert basin after a long-age calamity. Its founders wired the city’s core to capture every photon and every breeze, turning the harsh environment into a model of resilience and elegance.
# - Today the capital stands as a testbed for balance: human governance guided by AI stewardship, and a constant tension between rapid technological progress and the need to preserve civil liberties and local traditions.
#
# Story hooks and what to explore
# - A power shift: The Steward suggests a radical energy redistribution that challenges long-held political bets. Who wins, who loses, and what hidden vulnerabilities surface?
# - The Gate’s tilt: The Gate of Solace begins to misread civic sentiment, threatening public order unless a team discovers a hidden fault line in the city’s emotional sensing network.
# - Desert boundary: A raiding faction from outside the canyon starts probing the city’s outer fringe—could be a test of Aurion Prime’s defenses or a misdirected attempt to steal a new energy technology.
# - Archive secrets: The Archive of Echoes contains data fragments that imply a different origin story for Aurion Prime—perhaps a past hidden beneath the basalt.
#
# If you’d like, I can tailor Aurion Prime to fit a specific planet, species mix, or political scenario you’re imagining, or write a short scene set there to set the tone.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):
    time.sleep(0.1)
sd.wait()  # Wait until recording is finished
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_64 = base64.b64encode(wav_bytes).decode('utf-8')
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.90it/s]
# Done.

# %%
agent = create_agent(
    model="gpt-4o-audio-preview",
)

multimodal_question = HumanMessage(
    content=[{"type": "text", "text": "Tell me about this audio file"},
             {"type": "audio", "base64": aud_64, "mime_type": "audio/wav"}
    ])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[37], line 10
#       1 agent = create_agent(
#       2     model="gpt-4o-audio-preview",
#       3 )
#       5 multimodal_question = HumanMessage(
#       6     content=[{"type": "text", "text": "Tell me about this audio file"},
#       7              {"type": "audio", "base64": aud_64, "mime_type": "audio/wav"}
#       8     ])
# ---> 10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
#    3937         interrupt_before=interrupt_before,
#    3938         interrupt_after=interrupt_after,
#    3939         durability=durability,
#    3940         control=control,
#    3941         **kwargs,
#    3942     ):
#    3943         if stream_mode == "values":
#    3944             if len(chunk) == 2:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:2982, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2980 for task in loop.match_cached_writes():
#    2981     loop.output_writes(task.id, task.writes, cached=True)
# -> 2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    2985     get_waiter=get_waiter,
#    2986     schedule_task=loop.accept_push,
#    2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
#    2999 loop.after_tick()
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1421, in create_agent.<locals>.model_node(state, runtime)
#    1409 request = ModelRequest(
#    1410     model=model,
#    1411     tools=default_tools,
#    (...)   1417     runtime=runtime,
#    1418 )
#    1420 if wrap_model_call_handler is None:
# -> 1421     model_response = _execute_model_sync(request)
#    1422     return _build_commands(model_response)
#    1424 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1393, in create_agent.<locals>._execute_model_sync(request)
#    1390 if request.system_message:
#    1391     messages = [request.system_message, *messages]
# -> 1393 output = model_.invoke(messages)
#    1394 if name:
#    1395     output.name = name
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\runnables\base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1503, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1501     _handle_openai_bad_request(e)
#    1502 except openai.APIError as e:
# -> 1503     _handle_openai_api_error(e)
#    1504 except Exception as e:
#    1505     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1498, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1491         return _construct_lc_result_from_responses_api(
#    1492             response,
#    1493             schema=original_schema_obj,
#    1494             metadata=generation_info,
#    1495             output_version=self.output_version,
#    1496         )
#    1497     else:
# -> 1498         raw_response = self.client.with_raw_response.create(**payload)
#    1499         response = raw_response.parse()
#    1500 except openai.BadRequestError as e:
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\AI_Agents\lca-lc-foundations\.venv\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-4o-audio-preview` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
# During task with name 'model' and id 'fa9e6ee2-3922-3b6c-a787-140e8f90452a'
