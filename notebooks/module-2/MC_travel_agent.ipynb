# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
            "transport": "streamable_http",
            "url": "https://mcp.kiwi.com"
        }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Fransisco to Tokyo on September 30")]},
    config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Fransisco to Tokyo on September 30', additional_kwargs={}, response_metadata={}, id='425441d4-df07-409e-a728-4b9457180fbd'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 974, 'prompt_tokens': 2596, 'total_tokens': 3570, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E6KcaAO2uPMVREIVBsn3xDxMShORM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fa4e5-ab5a-75d0-9e38-bd0570ff2814-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '30/09/2026', 'departureDateFlexDays': 0, 'returnDate': None, 'adults': 1, 'cabinClass': 'M', 'currency': 'EUR', 'locale': 'en', 'max_sector_stopovers': 0}, 'id': 'call_MbTmw0d8t31wRkekaNCcB1Gh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2596, 'output_tokens': 974, 'total_tokens': 3570, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "San Francisco → Tokyo on 30/09/2026, 1 adult, economy [≤0 stops/sector]",\n  "currency": "EUR",\n  "passengers": {\n    "adults": 1,\n    "children": 0,\n    "infants": 0\n  },\n  "resultsCount": 15,\n  "itineraries": [\n    {\n      "id": "0f9c188450f60000c1fa1884_0|0f9c188450f60000c1fa1884_1",\n      "price": 410,\n      "priceFormatted": "410 EUR",\n      "totalDurationSeconds": 40500,\n      "bookingUrl": "https://kiwi.com/u/x9t2fc",\n      "outbound": {\n        "from": "SFO",\n        "to": "HND",\n        "departureTime": "2026-09-30T01:10:00",\n        "arrivalTime": "2026-10-01T04:25:00",\n        "durationSeconds": 40500,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "HND"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "HND",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2026-09-30T01:10:00",\n            "arrivalTime": "2026-10-01T04:25:00",\n            "durationSeconds": 40500,\n            "carrier": "NH",\n            "flightNumber": "NH107",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f50f60000d665b9e2_0",\n      "price": 499,\n      "priceFormatted": "499 EUR",\n      "totalDurationSeconds": 38700,\n      "bookingUrl": "https://kiwi.com/u/yz9j6d",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2026-09-30T17:15:00",\n        "arrivalTime": "2026-10-01T20:00:00",\n        "durationSeconds": 38700,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2026-09-30T17:15:00",\n            "arrivalTime": "2026-10-01T20:00:00",\n            "durationSeconds": 38700,\n            "carrier": "ZG",\n            "flightNumber": "ZG25",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c10ff50f6000067ed4d98_0|0f9c10ff50f6000067ed4d98_1",\n      "price": 523,\n      "priceFormatted": "523 EUR",\n      "totalDurationSeconds": 40200,\n      "bookingUrl": "https://kiwi.com/u/nbs28n",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2026-09-30T12:15:00",\n        "arrivalTime": "2026-10-01T15:25:00",\n        "durationSeconds": 40200,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2026-09-30T12:15:00",\n            "arrivalTime": "2026-10-01T15:25:00",\n            "durationSeconds": 40200,\n            "carrier": "NH",\n            "flightNumber": "NH7",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f50f6000095e06285_0",\n      "price": 837,\n      "priceFormatted": "837 EUR",\n      "totalDurationSeconds": 38100,\n      "bookingUrl": "https://kiwi.com/u/hzq2qw",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2026-09-30T13:55:00",\n        "arrivalTime": "2026-10-01T16:30:00",\n        "durationSeconds": 38100,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo" ...
#               AIMessage(content='Here are nonstop options from San Francisco (SFO) to Tokyo (HND/NRT) on 30 Sep 2026. Prices in EUR. All are direct (0 stops).\n\nCheapest options\n| Route | Times (dep → arr) | Cabin | Price | Booking |\n|---|---|---|---|---|\n| SFO → HND | 30 Sep 01:10 → 01 Oct 04:25 (11h 15m) | Economy | 410 EUR | https://kiwi.com/u/x9t2fc |\n\nOther notable options (mid-range prices)\n| Route | Times (dep → arr) | Cabin | Price | Booking |\n|---|---|---|---|---|\n| SFO → NRT | 30 Sep 17:15 → 01 Oct 20:00 (10h 45m) | Economy | 499 EUR | https://kiwi.com/u/yz9j6d |\n| SFO → NRT | 30 Sep 12:15 → 01 Oct 15:25 (11h 10m) | Economy | 523 EUR | https://kiwi.com/u/nbs28n |\n| SFO → NRT | 30 Sep 13:55 → 01 Oct 16:30 (10h 35m) | Economy | 837 EUR | https://kiwi.com/u/nbs28n |\n\nShortest-duration options (fastest)\n| Route | Times (dep → arr) | Cabin | Price | Booking |\n|---|---|---|---|---|\n| SFO → NRT | 30 Sep 13:55 → 01 Oct 16:30 (10h 35m) | Economy | 837 EUR | https://kiwi.com/u/hrk3r3 |\n| SFO → HND | 30 Sep 12:25 → 01 Oct 15:05 (10h 40m) | Economy | 883 EUR | https://kiwi.com/u/hrk3r3 |\n| SFO → NRT | 30 Sep 12:15 → 01 Oct 15:25 (11h 10m) | Economy | 523 EUR | https://kiwi.com/u/nbs28n |\n\nRecommendation\n- Best value: 410 EUR nonstop SFO → HND (NH107), depart 01:10 on 30 Sep, arrive 04:25 on 01 Oct.\n- Quickest nonstop option: 10h 35m SFO → NRT (JL57), depart 13:55 on 30 Sep, arrive 16:30 on 01 Oct, 837 EUR.\n\nHave a fantastic trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world, offering a culinary scene as diverse as the city itself.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5399, 'prompt_tokens': 7326, 'total_tokens': 12725, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 4800, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2432}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E6KcrPGLcvPv5JEv1c7TP4GR93UiT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fa4e5-ea19-7250-a8ea-849ed72f1e19-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7326, 'output_tokens': 5399, 'total_tokens': 12725, 'input_token_details': {'audio': 0, 'cache_read': 2432}, 'output_token_details': {'audio': 0, 'reasoning': 4800}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are nonstop options from San Francisco (SFO) to Tokyo (HND/NRT) on 30 Sep 2026. Prices in EUR. All are direct (0 stops).
#
# Cheapest options
# | Route | Times (dep → arr) | Cabin | Price | Booking |
# |---|---|---|---|---|
# | SFO → HND | 30 Sep 01:10 → 01 Oct 04:25 (11h 15m) | Economy | 410 EUR | https://kiwi.com/u/x9t2fc |
#
# Other notable options (mid-range prices)
# | Route | Times (dep → arr) | Cabin | Price | Booking |
# |---|---|---|---|---|
# | SFO → NRT | 30 Sep 17:15 → 01 Oct 20:00 (10h 45m) | Economy | 499 EUR | https://kiwi.com/u/yz9j6d |
# | SFO → NRT | 30 Sep 12:15 → 01 Oct 15:25 (11h 10m) | Economy | 523 EUR | https://kiwi.com/u/nbs28n |
# | SFO → NRT | 30 Sep 13:55 → 01 Oct 16:30 (10h 35m) | Economy | 837 EUR | https://kiwi.com/u/nbs28n |
#
# Shortest-duration options (fastest)
# | Route | Times (dep → arr) | Cabin | Price | Booking |
# |---|---|---|---|---|
# | SFO → NRT | 30 Sep 13:55 → 01 Oct 16:30 (10h 35m) | Economy | 837 EUR | https://kiwi.com/u/hrk3r3 |
# | SFO → HND | 30 Sep 12:25 → 01 Oct 15:05 (10h 40m) | Economy | 883 EUR | https://kiwi.com/u/hrk3r3 |
# | SFO → NRT | 30 Sep 12:15 → 01 Oct 15:25 (11h 10m) | Economy | 523 EUR | https://kiwi.com/u/nbs28n |
#
# Recommendation
# - Best value: 410 EUR nonstop SFO → HND (NH107), depart 01:10 on 30 Sep, arrive 04:25 on 01 Oct.
# - Quickest nonstop option: 10h 35m SFO → NRT (JL57), depart 13:55 on 30 Sep, arrive 16:30 on 01 Oct, 837 EUR.
#
# Have a fantastic trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world, offering a culinary scene as diverse as the city itself.
